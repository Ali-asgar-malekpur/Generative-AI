# %%
integer_number = 10
float_number = 1.23
new_number = integer_number + float_number
print(new_number)
print(type(new_number))

print('Good Morning!', end=' ')
print('It is rainy Day today!')

x=5
y=10
print('the value of x is {} and y is {}'.format(x,y))

number = int(input('Enter a number: '))
print(number)

a = 5
b = 6

print((a>2) and (b>6))#True

grade = 40
result = 'pass' if grade > 50 else 'fail'

languages = ['Switft', 'Python', 'Go']
for lang in languages:
    print(lang)

for number in range(0,4) #0, 1, 2, 3
    print(number)

for _ in range(0,4):
    print('Hello!')

number = 1
while number <= 3:
    print(number)
    number = number+1

number = int(input('Enter a number'))
while number != 0:
    print('You Entered Number: ', number)
    number = int(input('Enter a number again!: '))
print("0 Was executed, as a result it's out of while Loop!")

import random
print(random.randrange(15,20))
list1 = [1,2,3,4,5]
print(random.choice(list1))
random.shuffle(list1)
random.random()

languages = ['a', 'b', 'c', 'd', 'e']
print(languages[1:4])

languages.append('f')
languages.insert(1,'aa')

language_new = [1,2,3,4,5]
languages.extend(language_new)
languages[0] = 'aaa'
languages.remove('a')

del languages[0:5]
languages.pop(5) #Removes at the index
languages.clear()
languages.index('a')
languages.count('d')
languages.sort(reverse=True)
languages.reverse()
language_new = languages.copy() #Creates new List

tuple_new = (1,2,3,4,5)
del tuple_new #We cannot delete single elements in a tuple

empty_set = set()
empty_set_2 = {}
set_new = {'a', 'a', 'b'}

set_new.add('new_element')
list_new_2 = ['a', 'a', 'b']
set_new.update(list_new_2)

set_new.discard('a')

A = {1,3,5}
B = {0,2,4}
print('Union of a and b: ', a|b)
print(A.union(B))

country_capital = {
    'Germany':'berlin',
    'Canada': 'Ottawa',
    'England': 'London'
}

print(country_capital)

my_dict = {
    1:'one', 
    2:'two'
}

my_dict = {
    (1,2): 'value', #Allowed
    [1, 2]: 'value', #Invalid
    'USA':['Chicago', 'California', 'NewYork']
}

print(country_capital['Germany'])
print(country_capital['England'])
country_capital['Italy'] = 'Rome'
del country_capital['Italy']

country_capital.clear()
country_capitals = {
  "United States": "Washington D.C.", 
  "Italy": "Rome" 
}

for country in country_capital:
    print(country)
    capital = country_capital[country]
    print(capital)

for country in country_capital:
    capital = country_capital[country]
    print(capital)

greet = 'hello'
print(greet[1])

def greet(name:str):
    print(f"Hello World! {name}")

greet(name = 'Ali')

# %%
def greet(name:str):
    print(f"Hello World! {name}")

greet(name = 'Ali')

def add_numbers(num1:int, num2:int) -> int:
    sum = num1 + num2
    return sum

summed_value = add_numbers(1, 2) #Paramertes!
print(summed_value) #arguments

def add_(a:int, b:str) #Parameters

add_(a, b) #Arguemnts

power = pow(2, 3)

def add_all(*numbers):
    return sum(numbers)

print(add_all(1,2,3,4,5,6,7,8,9))

def greet_2(**words):
    for key, value in words.items():
        print(f"{key}, {value}")

greet(name="John", greeting="Hello")

#Local, Global, NonLocal Scope

# %%
c = 1
def add():

    global c
    c= c+2
    print(c)

add()

# %%
def factorial(num):
    if num == 1:
        return 1
    else:
        return (num*factorial(num-1))

num = 6
print(f"factorial of this {num} is {factorial(num)}")

import math
print(dir(math))

print(dir())

# %%
import os
current = os.getcwd()
os.chdir()

import os
os.chdir('C:\\python33')
print(os.getcwd())

import os
os.listdir()
os.listdir

import shutil
shutil.rmtree

# %%
import csv

with open('people.csv', 'r') as file:
    reader = csv.reader(file)

    for row in reader:
        print(row)

with open('people_csv.csv', 'r') as file:
    reader = csv.reader(file)

with open('dag_definiitions.csv', 'r') as file_obj:
    reader = csv.reader(file_obj)
    for row in reader:
        print(row)

with open('people_csv.csv', 'r') as file:
    csv_file = csv.DictReader(file)        

import pandas as pd
df = pd.read_csv('people,csv')

df = pd.DataFrame(['Jack', 24], ['Rose', 22])
df.to_csv('person')

import csv
with open('people.csv', 'r') as file_obj:
    reader = csv.reader(file_obj, skipinitialspace=True)

import csv
csv.register_dialect('my_dialect',
                     delimiter='|',
                     escapechar='\n',
                     quoting=csv.QUOTE_ALL)

try:

except ZeroDivisionError:

except IndexError:

except:
    raise Exception('exception occured!')

try:
    input_num = int(input('Number: '))
    if input_num < number:
        raise Exception
    else:
        print('')
except InvalidException:

# %%
class Bike:
    name = ''
    gear = 0

bike1 = Bike()
bike1.name = 'KTM'
bike1.gear = 4

print(bike1.name)

# %%
class Room:

    def __init__(self, l, b):
        self.length = l
        self.breadth = b

    def calculate_area(self):
        print('Area of room = ',self.length*self.breadth)

study_room = Room()

study_room.length=5
study_room.breadth=5
study_room.calculate_area()

# %%
class Animal:
    name = ''
    def eat(self):
        print('I can eat!')

class Dog(Animal):
    def display(self):
        print("My name is", self.name)

labra = Dog()
labra.name=''

# %%
class Cat:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def info(self):
        print(f"I am a cat. My name is {self.name}. I am {self.age} years old.")

    def make_sound(self):
        print("Meow")


class Dog:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def info(self):
        print(f"I am a dog. My name is {self.name}. I am {self.age} years old.")

    def make_sound(self):
        print("Bark")


cat1 = Cat("Kitty", 2.5)
dog1 = Dog("Fluffy", 4)

for animal in (cat1, dog1):
    animal.make_sound()
    animal.info()
    animal.make_sound()

# %%
numbers = [1,2,3,4,5]
double_numbers = [num*2 for number in numbers]
triple_numbers = [num*3 for num in numbers if num%2==0]
even_numbers = ['Even' if num%2==0 else 'Odd' for num in numbers]
multiplication = [[i * j for j in range(1, 6)] for i in range(2, 5)]


numbers = [1,2,3,4,5]

greet = lambda : print('Hello World')
greet()

greet_name = lambda name : print('my name is', name)
greet_name('Ali')

# %%
my_list = [1, 5, 4, 6, 8, 11, 3, 12]

new_list = list(filter(lambda x: (x%2==0), my_list))
#Filter takes 2 arguments: Function(def, lambda), Iterable:List

neww_list = list(map(lambda x: x*2, my_list))

lisstt = [1,2,3,4]
iterabor_obj = iter(lisstt)
next(iterabor_obj)

def get_numbers(n):
    return [i for i in range(n)]

def generate_numbers(n):
    for i in range(n):
        yield i

object_gen = generate_numbers(3)
print(next(object_gen))

def smart_divide(func):
    def wrapper(a, b):
        pass

class Employeee:
    def __init__(self, name, salary):
        self.name = name #public
        self.__salary = salary #Private

emp = Employeee('Alice', 5000)
print(emp.name)
print(emp.__salary)

# %%
import re
test_string = 'abyss'
result = re.match('^a...s$', test_string)

[a-e]
[^abc]
'ma*n''
'?':Zero or one

import re
text = 'contact: 123-456, Emergency: 999-048'
results = re.findall(r'\d{3}-\d{2}')

re.findall()
re.search
re.split(',;:', text_string)
re.sub('\d+', 'ID', text)

# %%
import datetime
current_date = datetime.date.today()
print(current_date)

datetime.time

d = datetime.date(2022)

print(datetime.date.today().year)

now = datetime.datetime.now()
now.strftime('')

import time
time.sleep(50)

# %%
import json
person = '{"name":"Bob", "languages":["English","Arabic"]}'
person_dict = json.load(person)
languages = person_dict['languages']

with open('path/to_json.json', 'r') as file_obj:
    data = json.load(file_obj)

print(data)

json_string = json.dumps(person_dict)

# %%
import json
person_string = '{"name": "Bob", "languages": "English", "numbers": [2, 1.6, null]}'

person_dict = json.loads(person_string)
print(json.dumps(person_dict, indent=4, sort_keys=True))

# %%
import pandas as pd
data = [1,2,3,4,5]
my_series = pd.Series(data)
print(my_series)

a = [1,2,3]
new_series = pd.Series(a, index=['x', 'y', 'z'])
print(new_series)

data1 = {
    'Name':[1,2,3],
    'Age':2
}

pd.DataFrame(data1)

data2 = [
    [],
    []
]

pd.read_csv()

df = pd.DataFrame(data)
df.set_index('Name', inplace=True)

pd.DataFrame(data, index = pd.RangeIndex(5, 8, nm))

second_row = df.iloc[1]

address = []
df['address'] = address

df.iloc[len(df.index)] = ['Any', 5.2, 'BIT']
df.sort_values('continent')
df.set_index(['continent', 'country'])

df.duplicated(subset=[''])
df.drop_duplicates(inplace=True, keep='last')

# %%
df.drop_duplicates(inplace=True, )
df_cleaned = df.dropna()
df_fill_na = df.fillna(0)

df.fillna(df.mean())
df['A'].fillna(df['B'].mean())

# %%
columns_with_nan = df.columns[df.isnull().all()]
df.drop(columns = [])

df['value'].aggregate('sum')

df.groupby('Cateogy')['Value'].agg(['sum', ''])

df.groupby([''])

# %%
from langchain.tools import tool

@tool
def add_numbers(a:int, b:int):
    """
        It will return the sum of numbers
    """
    return a+b

from langchain_openai import ChatOpenAI
from langchain.agents import create_agent

llm = ChatOpenAI(model = 'gpt-4o')
agent = create_agent(
    model=llm,
    tools=[add_numbers],
    system_prompt='You are a Math Teacher'
)
res = agent.invoke({'messages':[{'role':'user', 'content':'What is 2+3'}]})

for response in res:
    print(res, end='\n')

print(response['messages'][-1].content)

from langchain_community.utilities import GoogleSerperAPIWrapper
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    model=llm,
    tools=[add_numbers],
    system_prompt='You are a Math Teacher',
    checkpointer=InMemorySaver()
)

# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_groq import ChatGroq
from langchain_community.utilities import GoogleBooksAPIWrapper
from langchain.agents import create_agent
from langgraph.checkpoint.memory import MemorySaver
import streamlit as st

llm = ChatGroq(model = 'openai/gpt-oss-20b', streaming = True)
search = GoogleSerperAPIWrapper()
tools = [search.run]

if 'memory' not in st.session_state:
    st.session_state.memory = MemorySaver()
    st.session_state.history = []

agent = create_agent(
    model = llm,
    tools = tools,
    checkpointer = st.session_state.memory,
    system_prompt = 'You are a amazing AI agent and can search on Google as well'
)

query = st.chat_input('Ask Anything: ')
if query:
    st.chat_message('user').markdown(query)
    st.session_state.history.append({'role':'user', 'content':query})

    response = agent.stream(
        {'messages':[{'role':'user', 'content':query}]},
        {'confgurable':{'thread_id':'Ali_constant'}}
        stream_mode='messages'
    )

from langchain_community.document_loaders import TextLoader
loader = TextLoader('.//data/speech.txt')
content = loader.load()
print(len(content))
print(content[0].page_content)

from langchain_text_splitters import RecursiveCharacterTextSplitter
text = ''
splitter = RecursiveCharacterTextSplitter(chunk_size = 50, chunk_overlap=10)
chunks = splitter.split_text(text)

from langchain_openai import OpenAIEmbeddings
embeddings = OpenAIEmbeddings(model = '')
vector = embeddings.embed_documents(docuements)

from langchain_chroma import Chroma
Chroma.from_texts(
    texts = docuements,
    embeddings=embeddings,
)

# %%
from pydantic import BaseModel
from langgraph.graph import StateGraph, START, END

graph = StateGraph

class GreetState(BaseModel):
    message: str = ''

def greet(state: GreetState):
    state.message = f"{state.message}! All Good"
    return state

def upperCase(state: GreetState):
    state.message = f"{state.message.upper()}"
    return state

finalGraph = graph.compile()
response = finalGraph.invoke({'message':'Hello There'})
